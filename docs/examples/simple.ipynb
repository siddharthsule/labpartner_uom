# %%
import numpy as np # For Arrays
import labpartner_uom as lp # For the Analysis

# %%
# "Unknown" Parameters
m = 2.01
c = 1.74

# Make some data
x = np.linspace(0, 10, 10)
y = m*x + c + np.random.normal(0, 0.5, 10) # Add some noise
yerr = np.full(10, 0.5)

# %%
lp.analyse(x, y, yerr, "Linear")
# Out:
# ----------------------------------------
# Fit Results
# Fit = A*x + B
# Fit Parameters:  ['A', 'B']
# Fit Parameter Values:  [2.00199845 1.63028251]
# Fit Parameter Errors:  [0.05817815 0.34509595]
# Reduced Chi-Squared:  1.378950819613738
#
# Plot saved as myplot.png and myplot.pdf
# ----------------------------------------

# %%
# "Unknown" Parameters
